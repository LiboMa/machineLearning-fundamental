# %% [markdown]
# #  Machine Learning from zero to Master  - Culculate Gradient Descent Derivative
#
# ### Reference Link
# - https://towardsdatascience.com/gradient-descent-in-python-a0d07285742f
# - http://sofasofa.io/tutorials/python_gradient_descent/index.php (implemented by Chinese)
# - back-propogation https://www.youtube.com/watch?v=d14TUNcbn1k
# - Power Rule - https://www.mathsisfun.com/calculus/power-rule.html
#
#
# This tutorial is used to calculate derivate of Gradient Descent in Python. Spaired by Machine Learning

# %%
# generate some sample data

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib

# %%
# np.random.seed(123)
X = 2 * np.random.rand(100,1)
y = 10 + 4 * X + np.random.randn(100,1)

plt.scatter(X, y, marker='o')
plt.xlabel("X")
plt.ylabel("y")
# print("X->",X,"\n y->",y)
# Out:
# Text(0, 0.5, 'y')

# %%
# x = np.linspace(0, 2, 100)

# # Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
# fig, ax = plt.subplots()  # Create a figure and an axes.
# ax.plot(x, x, label='linear')  # Plot some data on the axes.
# ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
# ax.plot(x, x**3, label='cubic')  # ... and some more.
# ax.set_xlabel('x label')  # Add an x-label to the axes.
# ax.set_ylabel('y label')  # Add a y-label to the axes.
# ax.set_title("Simple Plot")  # Add a title to the axes.
# ax.legend()  # Add a legend.

## some helps
# import matplotlib
# matplotlib.colors
# matplotlib.axes.Axes.imshow
# matplotlib.figure.Figure.text
# matplotlib.axes.Axes.set_axis_off

# %%
# the best theta
theta_best = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
theta_best
# Out:
# array([[11.355025]])

# %% [markdown]
#     Like climb down from the mountain ->
#     Size of Steps took in any direction = Learning rate
#     Gadget tells you height = Cost function
#     The direction of your steps = Gradients

# %% [markdown]
# Images for equation
# ![image.png](attachment:image.png)

# %% [markdown]
# gradient descents
# ![image.png](attachment:image.png)

# %%
# implement cost function into python code
def cal_cost_function(theta, X, y):
    m = len(y)
    
    predictions = X.dot(theta)
    cost = (1/2*m) * np.sum(np.square(predictions - X))
    return cost

# %%
cal_cost_function(theta_best, X, y)
# Out:
# 775786.4844752841

# %%
def gradient_descent(X, y, theta, learning_rate=0.01, interation=100):
    '''
    X = Matrix with bias added units
    y = Vector y(result, moving steps)
    theta = Vector of thetas
    learning rate
    interation = total moving steps numbers
    
    Returns final theta and array of theta of history
    '''  
    m = len(y)
    
    cost_history = np.zeros(interation)
    theta_history = np.zeros((interation,2))
    
    for i in range(interation):
        predictions = np.dot(X, theta)
        theta = theta - learning_rate*(1/m)*(X.T.dot(predictions - y))
        theta_history[i,:] = theta.T
        cost_history[i] = cal_cost_function(theta, X, y)
    
    return theta, cost_history, theta_history

# %%
# find cost
lr = 0.015
loop = 2000

theta = np.random.randn(2,1)

# X_b = np.c_[np.ones((len(X),1)),X] # add one more feature -> 1,for easy calculation 
X_b = np.c_[np.ones((len(X),1)),X]


theta, cost_history, theta_history = gradient_descent(X_b, y, theta, learning_rate=lr, interation=loop)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-401-7304e754d5ce> in <module>
#       9
#      10
# ---> 11 theta, cost_history, theta_history = gradient_descent(X_b, y, theta, learning_rate=lr, interation=loop)
#
# <ipython-input-400-9bec509fdfe8> in gradient_descent(X, y, theta, learning_rate, interation)
#      15
#      16     for i in range(interation):
# ---> 17         predictions = theta.T.dot(X)
#      18         theta = theta - learning_rate*(1/m)*(X.T.dot(predictions - y))
#      19         theta_history[i,:] = theta.T
#
# ValueError: shapes (1,2) and (100,2) not aligned: 2 (dim 1) != 100 (dim 0)

# %%
print("Theta 0 {}, Theta 1 {}\n".format(theta[0], theta[1]),
"Cost_history : {}\n".format(cost_history),
)
# print("Theta_history : {}\n".format(theta_history))
# Out:
# Theta 0 [9.89603523], Theta 1 [4.11296379]
#  Cost_history : [  76202.89122778   48921.16655231   28392.44393521 ... 1791947.72438895
#  1791949.81811108 1791951.90747851]

# %%
plt.plot(range(loop), cost_history)
plt.title("cost function learning progress")
plt.xlabel("interations")
plt.ylabel("J(θ)", rotation=0, fontsize=14)
# Out:
# Text(0, 0.5, 'J(θ)')

# %%
plt.plot(range(loop), theta_history)
plt.title("theta history function learning progress")
plt.xlabel("interations")
plt.ylabel("predictions")
# Out:
# Text(0, 0.5, 'predictions')

# %%
fig,ax = plt.subplots(figsize=(12,8))

ax.set_ylabel('J(Theta)')
ax.set_xlabel('Iterations')
_=ax.plot(range(loop),cost_history,'b.')

# %%
def plot_GD(n_iter,lr,ax,ax1=None):
     """
     n_iter = no of iterations
     lr = Learning Rate
     ax = Axis to plot the Gradient Descent
     ax1 = Axis to plot cost_history vs Iterations plot

     """
     _ = ax.plot(X,y,'b.')
     theta = np.random.randn(2,1)

     tr =0.1
     cost_history = np.zeros(n_iter)
     for i in range(n_iter):
        pred_prev = X_b.dot(theta)
        theta,h,_ = gradient_descent(X_b,y,theta,lr,1)
        pred = X_b.dot(theta)

        cost_history[i] = h[0]

        if ((i % 25 == 0) ):
            _ = ax.plot(X,pred,'r-',alpha=tr)
            if tr < 0.8:
                tr = tr+0.2
     if not ax1== None:
        _ = ax1.plot(range(n_iter),cost_history,'b.')

# %%
fig = plt.figure(figsize=(30,25),dpi=200)
fig.subplots_adjust(hspace=0.4, wspace=0.4)

it_lr =[(2000,0.001),(500,0.01),(200,0.05),(100,0.1)]
count =0
for n_iter, lr in it_lr:
    count += 1
    
    ax = fig.add_subplot(4, 2, count)
    count += 1
   
    ax1 = fig.add_subplot(4,2,count)
    
    ax.set_title("lr:{}".format(lr))
    ax1.set_title("Iterations:{}".format(n_iter))
    plot_GD(n_iter,lr,ax,ax1)
