# %%
# define a Neuron networks class
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage
# from lr_utils import load_dataset
# %matplotlib inline

# %%
# define neronal network initializer
from random import seed
from random import random

def NeuronNetwork_initializer(n_inputs, n_hidden, n_outputs):
    network = list()
    
    hidden_layer = [{'weights':[random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer)
    output_layer = [{'weights':[random() for i in range(n_hidden +1)]} for i in range(n_outputs)]
    network.append(output_layer)
    return network

# %%
seed(11)
network = NeuronNetwork_initializer(2,1,2)

# %%
network
# Out:
# [[{'weights': [0.4523795535098186, 0.559772386080496, 0.9242105840237294]}],
#  [{'weights': [0.4656500700997733, 0.5078412730622711]},
#   {'weights': [0.587384828849897, 0.18466034385487662]}]]

# %%
for layer in network:
    print(layer)
# Out:
# [{'weights': [0.4523795535098186, 0.559772386080496, 0.9242105840237294]}]
# [{'weights': [0.4656500700997733, 0.5078412730622711]}, {'weights': [0.587384828849897, 0.18466034385487662]}]

# %%
# define an activate function for each neuron computes
# you can think bias that always is 1.0
# assumes that the bias is the last weight in the list of weights
from math import exp

def activate(weights, inputs):
    activation = weights[-1]
    for i in range(len(weights) - 1):
        activation += weights[i] * inputs[i]
    return activation

# output = 1 / (1 + e^(-activation))
def activation_sigmoid_transfer(activation):
    return 1.0/(1.0+exp(-activation))
def der_activation_sigmoid_transfer(output):
    return output*(1.0 - output)

def SME(predict, target):
    return (predict - target)**2

# %%
# forward propgation 
def forward_propagate(network, inputs):
    ''' inputs , the data set as inputs, and go for network forwar traversing 
        returns, hypothesis output
    '''
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)
            neuron['output'] = activation_sigmoid_transfer(activation)
            new_inputs.append(neuron['output'])
        inputs = new_inputs
    return inputs

# %%
network = network
inputs = [1, 0, None]
output = forward_propagate(network, inputs)
pprint(network)
pprint(output)
# Out:
# [[{'output': 0.7984428030302543,
#    'weights': [0.4523795535098186, 0.559772386080496, 0.9242105840237294]}],
#  [{'output': 0.7067468313232838,
#    'weights': [0.4656500700997733, 0.5078412730622711]},
#   {'output': 0.6578333050656483,
#    'weights': [0.587384828849897, 0.18466034385487662]}]]
# [0.7067468313232838, 0.6578333050656483]

# %%
# output error calculate for output layer, 
# This error calculation is used for neurons in the output layer. 
# The expected value is the class value itself.
# error = (expected - output) * der_activation_sigmoid_transfer(output)

# output error calculate for hidden layer, 
# error = (weight_k * error_j) * transfer_derivative(output)

def backward_propagate_error(network, expected):
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = []
        #looping index from last -> first layer. e.g. 2,1,0
        if i != len(network)-1:
            # back forward for hidden layers
            print("hidden layer", i)
            for j in range(len(layer)):
                error = 0.0
                previous_layer = network[i+1]
                for neuron in previous_layer:
                    error +=(neuron['weights'][j] * neuron['delta'])
                    print("get error delta from previous layer ", neuron)
                print("set error in hidden layer", j)
                errors.append(error)
        else:
            # back forward for output layer
            print("output layer", i)
            for j in range(len(layer)):
                neuron = layer[j]
                print("set error in output layer", j)
                errors.append(expected[j] - neuron['output'])
        # calculate delta for each neuron        
        for j in range(len(layer)):
            neuron = layer[j]
            print("layer %d neuron %d th ->"% (i,j))
#             print("Layer{}, neurons: {}".format(j, neuron))
            # gredient descent to minimize the delta??? NOT Sure
            neuron['delta'] = errors[j] * der_activation_sigmoid_transfer(neuron['output'])
            print("update delta: ", neuron['delta'])

# %%
from pprint import pprint
network = network
expected = [0, 1]
backward_propagate_error(network, expected)
# Out:
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.14647734298721501
# layer 1 neuron 1 th ->
# update delta:  0.07701783868909282
# hidden layer 0
# get error delta from previous layer  {'weights': [0.4656500700997733, 0.5078412730622711], 'output': 0.7067468313232838, 'delta': -0.14647734298721501}
# get error delta from previous layer  {'weights': [0.587384828849897, 0.18466034385487662], 'output': 0.6578333050656483, 'delta': 0.07701783868909282}
# set error in hidden layer 0
# layer 0 neuron 0 th ->
# update delta:  -0.0036962958010029402

# %%
for layer in network:
    pprint(layer)
# Out:
# [{'delta': -0.0036962958010029402,
#   'output': 0.7984428030302543,
#   'weights': [0.4523795535098186, 0.559772386080496, 0.9242105840237294]}]
# [{'delta': -0.14647734298721501,
#   'output': 0.7067468313232838,
#   'weights': [0.4656500700997733, 0.5078412730622711]},
#  {'delta': 0.07701783868909282,
#   'output': 0.6578333050656483,
#   'weights': [0.587384828849897, 0.18466034385487662]}]

# %%
# update weights
# weight = weight + learning_rate*error*input

# when forward and backforward propagation has performed, then we will need update weights
def update_weights(network, inputs, l_rate):
    for i in range(len(network)):
        inputs = inputs[:-1]
        if i !=0:
            inputs = [neuron['output'] for neuron in network[i - 1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                '''gradient descent here for weights'''
                neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j] # for weights with inputs, gradient descent
                print("update weights for neuron", neuron['weights'][j])
            '''gradient descent here for bias'''    
            neuron['weights'][-1] += l_rate * neuron['delta'] # for bias

# %%
# when forward and backforward propagation has performed, then we will need update weights
def update_weights_batch_gradient(network, inputs, l_rate):
    for i in range(len(network)):
        sum_der_weights = 0.0
        inputs = inputs[:-1]
        if i !=0:
            inputs = [neuron['output'] for neuron in network[i - 1]]
        
        for neuron in network[i]:            
            for j in range(len(inputs)):
                '''gradient descent here for weights'''
                neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j] # for weights with inputs, gradient descent
                
            '''gradient descent here for bias'''    
            neuron['weights'][-1] += l_rate * neuron['delta'] # for bias

# %% [markdown]
# ## Train network
#
# The network is updated using **stochastic gradient descent**
# Because updates are made for each training pattern, this type of learning is called online learning. If errors were accumulated across an epoch before updating the weights, this is called batch learning or batch gradient descent.

# %%
def train_network(network, train_sets, l_rate, n_epoch, n_outputs):
    error_history = []
    
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train_sets:
            outputs = forward_propagate(network, row)
            target = [0 for i in range(n_outputs)] # numbers of set({[0,1]) -> 2
            target[row[-1]] = 1
            print("target for each row->",target)

#             sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
            for i in range(len(target)):
                _error = SME(target[i], outputs[i])
                sum_error = sum_error + _error
#                 print("__error {}, sum_error :{}".format(_error, sum_error))
            backward_propagate_error(network, target)
            update_weights_batch_gradient(network, row, l_rate)
        error_history.append(sum_error)
        print('>epoch={}, lrate={:.3f}, error={:.3f}, accuracy {:.2f}%'.format(epoch, l_rate, sum_error, 100*(1.0-sum_error)))
    return epoch, error_history, network

# %%
# Test training backprop algorithm
seed(1)
dataset = [[2.7810836,2.550537003,0],
	[1.465489372,2.362125076,0],
	[3.396561688,4.400293529,0],
	[1.38807019,1.850220317,0],
	[3.06407232,3.005305973,0],
	[7.627531214,2.759262235,1],
	[5.332441248,2.088626775,1],
	[6.922596716,1.77106367,1],
	[8.675418651,-0.242068655,1],
	[7.673756466,3.508563011,1]]
n_inputs = len(dataset[0]) - 1
n_outputs = len(set([row[-1] for row in dataset]))
network = NeuronNetwork_initializer(n_inputs, 2, n_outputs)
epoch, error_history, network = train_network(network, dataset, 0.5, 10, n_outputs)
# for layer in network:
# 	print(layer)
# Out:
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.029379162360871295
# layer 1 neuron 1 th ->
# update delta:  -0.13553299084477086
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.0938595867742349], 'output': 0.8094918973879515, 'delta': 0.029379162360871295}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.43276706790505337], 'output': 0.7734292563511262, 'delta': -0.13553299084477086}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.0938595867742349], 'output': 0.8094918973879515, 'delta': 0.029379162360871295}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.43276706790505337], 'output': 0.7734292563511262, 'delta': -0.13553299084477086}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.000525476610401129
# layer 0 neuron 1 th ->
# update delta:  -0.0067428584755714034
# 0.0014613943833701694
# 0.0013402475390390943
# update weights for neuron 0.0028016419224092637
# -0.01875245312353263
# -0.017197910047937037
# update weights for neuron -0.0331487212490604
# 0.0283329649798022
# 0.026985521432844786
# update weights for neuron 0.055318486412646986
# -0.13070663608596025
# -0.12449056186061569
# update weights for neuron -0.19987871153392894
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.030429884028505355
# layer 1 neuron 1 th ->
# update delta:  -0.13959044542134827
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.10854916795467054], 'output': 0.8056538685579417, 'delta': 0.030429884028505355}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.36500057248266793], 'output': 0.755327596075077, 'delta': -0.13959044542134827}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.10854916795467054], 'output': 0.8056538685579417, 'delta': 0.030429884028505355}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.36500057248266793], 'output': 0.755327596075077, 'delta': -0.13959044542134827}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0007415716591109918
# layer 0 neuron 1 th ->
# update delta:  -0.00980191768833596
# 0.0010867653850035654
# 0.0017516850116369976
# update weights for neuron 0.002838450396640563
# -0.014364606197475156
# -0.02315335556450632
# update weights for neuron -0.03467951136534091
# 0.028934556311296402
# 0.02677112619101549
# update weights for neuron 0.05570568250231189
# -0.13273095618042466
# -0.12280669311569925
# update weights for neuron -0.19983196679381202
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.0258106162172377
# layer 1 neuron 1 th ->
# update delta:  -0.13932538967131136
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.12376410996892322], 'output': 0.8228967581646878, 'delta': 0.0258106162172377}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.2952053497719938], 'output': 0.7566361100884026, 'delta': -0.13932538967131136}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.12376410996892322], 'output': 0.8228967581646878, 'delta': 0.0258106162172377}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.2952053497719938], 'output': 0.7566361100884026, 'delta': -0.13932538967131136}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  8.98979292370395e-05
# layer 0 neuron 1 th ->
# update delta:  -0.002765927460304773
# 0.0003053438622770634
# 0.0003955772762922448
# update weights for neuron 0.0007009211385693082
# -0.009394643243458333
# -0.012170892705262497
# update weights for neuron -0.02086461481015152
# 0.025629028444010913
# 0.025044916568462038
# update weights for neuron 0.05067394501247295
# -0.13834518109932573
# -0.13519215236155632
# update weights for neuron -0.22286338844840908
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.03105332930159928
# layer 1 neuron 1 th ->
# update delta:  -0.14479100079015744
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.13666941807754207], 'output': 0.8033975978125357, 'delta': 0.03105332930159928}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.22554265493633813], 'output': 0.723040350499272, 'delta': -0.14479100079015744}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.13666941807754207], 'output': 0.8033975978125357, 'delta': 0.03105332930159928}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.22554265493633813], 'output': 0.723040350499272, 'delta': -0.14479100079015744}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.001112738694894046
# layer 0 neuron 1 th ->
# update delta:  -0.01251412287333398
# 0.0015445594116419306
# 0.0020588117408050282
# update weights for neuron 0.003603371152446959
# -0.017370480914472044
# -0.02315388438967695
# update weights for neuron -0.03692099415170204
# 0.02873849458670514
# 0.02629931488700853
# update weights for neuron 0.05503780947371367
# -0.13399772217651584
# -0.12262466563897031
# update weights for neuron -0.20158457834177249
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.02613174505779241
# layer 1 neuron 1 th ->
# update delta:  -0.14467830078905927
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.1521960827283417], 'output': 0.82166489581817, 'delta': 0.02613174505779241}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.1531471545412594], 'output': 0.7239540081906806, 'delta': -0.14467830078905927}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.1521960827283417], 'output': 0.82166489581817, 'delta': 0.02613174505779241}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.1531471545412594], 'output': 0.7239540081906806, 'delta': -0.14467830078905927}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.00029760369195950084
# layer 0 neuron 1 th ->
# update delta:  -0.005897862730357044
# 0.0009118792348629132
# 0.0008943901530327399
# update weights for neuron 0.0018062693878956532
# -0.018071477939246645
# -0.017724882091476112
# update weights for neuron -0.033990090642827105
# 0.025515567514466524
# 0.02449239471625285
# update weights for neuron 0.05000796223071938
# -0.14126683631335704
# -0.13560204425558364
# update weights for neuron -0.2268609183382213
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.11760703012302898
# layer 1 neuron 1 th ->
# update delta:  0.057720942815902114
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.1652619552572379], 'output': 0.8287798213128459, 'delta': -0.11760703012302898}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.08080800414672977], 'output': 0.7160881948274291, 'delta': 0.057720942815902114}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.1652619552572379], 'output': 0.8287798213128459, 'delta': -0.11760703012302898}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.08080800414672977], 'output': 0.7160881948274291, 'delta': 0.057720942815902114}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0011701706800606815
# layer 0 neuron 1 th ->
# update delta:  -0.0010059009024146112
# -0.008925513387870456
# -0.003228807765995706
# update weights for neuron -0.012154321153866162
# -0.0076725405313582155
# -0.002775544372185057
# update weights for neuron -0.022602406057409437
# -0.11574242442859735
# -0.1148867500061354
# update weights for neuron -0.23062917443473274
# 0.0568058036567047
# 0.05638584292513713
# update weights for neuron -0.11743752785289091
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.12312805404153349
# layer 1 neuron 1 th ->
# update delta:  0.057668366019423274
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.10645844019572342], 'output': 0.8143186751238907, 'delta': -0.12312805404153349}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.10966847555468083], 'output': 0.7162494822834369, 'delta': 0.057668366019423274}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.10645844019572342], 'output': 0.8143186751238907, 'delta': -0.12312805404153349}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.10966847555468083], 'output': 0.7162494822834369, 'delta': 0.057668366019423274}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0028214822934577877
# layer 0 neuron 1 th ->
# update delta:  -0.002585311537211641
# -0.015045388562135949
# -0.005893023463304343
# update weights for neuron -0.020938412025440292
# -0.013786021879957642
# -0.005399750898336641
# update weights for neuron -0.04012418480373458
# -0.11853664594110108
# -0.11623465245654056
# update weights for neuron -0.23477129839764166
# 0.05551792999620012
# 0.054439766259468086
# update weights for neuron -0.12481360214197346
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.1260083067901263
# layer 1 neuron 1 th ->
# update delta:  0.055144720784699126
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.04489441317495668], 'output': 0.8060625442634727, 'delta': -0.1260083067901263}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.13850265856439248], 'output': 0.7240207229348242, 'delta': 0.055144720784699126}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, 0.04489441317495668], 'output': 0.8060625442634727, 'delta': -0.1260083067901263}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.13850265856439248], 'output': 0.7240207229348242, 'delta': 0.055144720784699126}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0030472957979460116
# layer 0 neuron 1 th ->
# update delta:  -0.002255335092815224
# -0.02109519988354166
# -0.005396954879485842
# update weights for neuron -0.0264921547630275
# -0.015612775307002226
# -0.003994342046561121
# update weights for neuron -0.046099272116590845
# -0.1210453854577816
# -0.1204291352639497
# update weights for neuron -0.2414745207217313
# 0.05297280912172913
# 0.052703120989747665
# update weights for neuron -0.1357985906102545
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.13389065213556872
# layer 1 neuron 1 th ->
# update delta:  0.055196867876946686
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.018109740220106474], 'output': 0.7798390390320552, 'delta': -0.13389065213556872}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.16607501895674204], 'output': 0.7238595226619582, 'delta': 0.055196867876946686}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.018109740220106474], 'output': 0.7798390390320552, 'delta': -0.13389065213556872}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.16607501895674204], 'output': 0.7238595226619582, 'delta': 0.055196867876946686}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.011019154685023902
# layer 0 neuron 1 th ->
# update delta:  -0.004096773351557757
# -0.09559578007271038
# 0.0026673919538406847
# update weights for neuron -0.0929283881188697
# -0.03554122394302394
# 0.0009917004150514282
# update weights for neuron -0.12747791164684222
# -0.11359387908889391
# -0.12392569707029988
# update weights for neuron -0.23751957615919378
# 0.04682945549739294
# 0.05108878191751445
# update weights for neuron -0.1396013387442864
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.13046528428911117
# layer 1 neuron 1 th ->
# update delta:  0.05013185921888201
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.08505506628789083], 'output': 0.7920188964765487, 'delta': -0.13046528428911117}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.19367345289521537], 'output': 0.739660044663141, 'delta': 0.05013185921888201}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.08505506628789083], 'output': 0.7920188964765487, 'delta': -0.13046528428911117}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.19367345289521537], 'output': 0.739660044663141, 'delta': 0.05013185921888201}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0007035483332888851
# layer 0 neuron 1 th ->
# update delta:  -0.0009583590721332153
# -0.0053988585717191055
# -0.0024684436586280825
# update weights for neuron -0.007867302230347189
# -0.007354214126532021
# -0.0033624631917428803
# update weights for neuron -0.018583979548622093
# -0.1293577903268341
# -0.12838240239112056
# update weights for neuron -0.2577401927179547
# 0.049706299793589974
# 0.04933150268995106
# update weights for neuron -0.15870239023441363
# >epoch=0, lrate=0.500, error=6.580, accuracy -558.05%
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.04112788620711149
# layer 1 neuron 1 th ->
# update delta:  -0.14339005814717
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.15028770843244643], 'output': 0.7686911470642551, 'delta': 0.04112788620711149}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.21873938250465638], 'output': 0.7334515094687983, 'delta': -0.14339005814717}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.15028770843244643], 'output': 0.7686911470642551, 'delta': 0.04112788620711149}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.21873938250465638], 'output': 0.7334515094687983, 'delta': -0.14339005814717}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0007865485027595535
# layer 0 neuron 1 th ->
# update delta:  -0.006674989369346682
# 0.002187457141629149
# 0.002006121060942489
# update weights for neuron 0.004193578202571638
# -0.0185637034652644
# -0.017024807381150347
# update weights for neuron -0.03139493264384311
# 0.03965197719937737
# 0.03770143381098272
# update weights for neuron 0.07735341101036008
# -0.1382443845432994
# -0.131443924911797
# update weights for neuron -0.1923348984447363
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.042183390331020185
# layer 1 neuron 1 th ->
# update delta:  -0.14596036563771425
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.12972376532889068], 'output': 0.7652094721838723, 'delta': 0.042183390331020185}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.14704435343107136], 'output': 0.7124060537022864, 'delta': -0.14596036563771425}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.12972376532889068], 'output': 0.7652094721838723, 'delta': 0.042183390331020185}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.14704435343107136], 'output': 0.7124060537022864, 'delta': -0.14596036563771425}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.001098743853035052
# layer 0 neuron 1 th ->
# update delta:  -0.00955851518279556
# 0.0016101974391731985
# 0.002595370407354955
# update weights for neuron 0.0042055678465281535
# -0.01400790241248753
# -0.022578408402608115
# update weights for neuron -0.032380742968567494
# 0.040094933537344835
# 0.037002106502468275
# update weights for neuron 0.0770970400398131
# -0.1387340162421025
# -0.1280324068806372
# update weights for neuron -0.18966938308292658
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.035891593785684045
# layer 1 neuron 1 th ->
# update delta:  -0.14584898570092034
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.10863207016338058], 'output': 0.7863582378015278, 'delta': 0.035891593785684045}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.07406417061221424], 'output': 0.7135307027305091, 'delta': -0.14584898570092034}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.10863207016338058], 'output': 0.7863582378015278, 'delta': 0.035891593785684045}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.07406417061221424], 'output': 0.7135307027305091, 'delta': -0.14584898570092034}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0001355175151742451
# layer 0 neuron 1 th ->
# update delta:  -0.002755864458590028
# 0.00046029360009379954
# 0.00059631684508739
# update weights for neuron 0.0010566104451811896
# -0.009360463637367752
# -0.01212661254393479
# update weights for neuron -0.020430465736121353
# 0.0356371474064808
# 0.03480158757996938
# update weights for neuron 0.07043873498645017
# -0.14481501806650263
# -0.14141963936259744
# update weights for neuron -0.2157959224426499
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.04240137446251856
# layer 1 neuron 1 th ->
# update delta:  -0.14807188962337897
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.09068627327053856], 'output': 0.7644933906846075, 'delta': 0.04240137446251856}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.0011396777617540682], 'output': 0.6753615606006504, 'delta': -0.14807188962337897}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.09068627327053856], 'output': 0.7644933906846075, 'delta': 0.04240137446251856}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.0011396777617540682], 'output': 0.6753615606006504, 'delta': -0.14807188962337897}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0016270050228179402
# layer 0 neuron 1 th ->
# update delta:  -0.011906126815936682
# 0.002258397171153853
# 0.0030103177490788014
# update weights for neuron 0.005268714920232655
# -0.016526539711561327
# -0.02202895773162457
# update weights for neuron -0.03328678252295324
# 0.039218117544504584
# 0.035776176568030865
# update weights for neuron 0.07499429411253544
# -0.13695548424780132
# -0.12493571576578853
# update weights for neuron -0.1868969059010544
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.035811385274133974
# layer 1 neuron 1 th ->
# update delta:  -0.14805398909706888
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.06948558603927929], 'output': 0.786634575113333, 'delta': 0.035811385274133974}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.07289626704993542], 'output': 0.6763237081574557, 'delta': -0.14805398909706888}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.06948558603927929], 'output': 0.786634575113333, 'delta': 0.035811385274133974}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.07289626704993542], 'output': 0.6763237081574557, 'delta': -0.14805398909706888}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0004437356062513292
# layer 0 neuron 1 th ->
# update delta:  -0.005732985955695974
# 0.0013596379885131168
# 0.0013335612678998959
# update weights for neuron 0.0026931992564130126
# -0.01756628357779678
# -0.017229376935778223
# update weights for neuron -0.03210246125716199
# 0.03496083548556892
# 0.033514050475407314
# update weights for neuron 0.06847488596097623
# -0.14453758535678465
# -0.1385561833395054
# update weights for neuron -0.21461888273531382
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.12934887047429658
# layer 1 neuron 1 th ->
# update delta:  0.07379246989017951
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.05157989340221231], 'output': 0.7957042952618982, 'delta': -0.12934887047429658}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.14692326159846986], 'output': 0.667511481027211, 'delta': 0.07379246989017951}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.05157989340221231], 'output': 0.7957042952618982, 'delta': -0.12934887047429658}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.14692326159846986], 'output': 0.667511481027211, 'delta': 0.07379246989017951}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.001291580245578372
# layer 0 neuron 1 th ->
# update delta:  -0.0009325444050729593
# -0.009851568638534819
# -0.0035638085950964273
# update weights for neuron -0.013415377233631245
# -0.007113011558135057
# -0.002573134559378359
# update weights for neuron -0.02310152335114466
# -0.12728324658673595
# -0.12628674834700063
# update weights for neuron -0.25356999493373655
# 0.07261404840131509
# 0.0720455543272528
# update weights for neuron -0.10891039220516867
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.13435577487391878
# layer 1 neuron 1 th ->
# update delta:  0.07318524092260018
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.1162543286393606], 'output': 0.7780664502691007, 'delta': -0.13435577487391878}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.1100270266533801], 'output': 0.6693332230029164, 'delta': 0.07318524092260018}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.1162543286393606], 'output': 0.7780664502691007, 'delta': -0.13435577487391878}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.1100270266533801], 'output': 0.6693332230029164, 'delta': 0.07318524092260018}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0030893926060927435
# layer 0 neuron 1 th ->
# update delta:  -0.0024182928249358395
# -0.016474004563995163
# -0.006452588115572332
# update weights for neuron -0.022926592679567495
# -0.012895404409430315
# -0.005050911143951382
# update weights for neuron -0.040872908232949194
# -0.1293098944487988
# -0.12666350397115744
# update weights for neuron -0.25597339841995626
# 0.0704366878743551
# 0.06899516647445096
# update weights for neuron -0.11654154407115021
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.13691134914469325
# layer 1 neuron 1 th ->
# update delta:  0.06978182503176752
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.18343221607632], 'output': 0.7676903003930035, 'delta': -0.13691134914469325}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.07343440619208001], 'output': 0.6795498286753973, 'delta': 0.06978182503176752}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.18343221607632], 'output': 0.7676903003930035, 'delta': -0.13691134914469325}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.07343440619208001], 'output': 0.6795498286753973, 'delta': 0.06978182503176752}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0033233521192097197
# layer 0 neuron 1 th ->
# update delta:  -0.0021473037151626497
# -0.023006226466552846
# -0.005885868200949843
# update weights for neuron -0.02889209466750269
# -0.01486491764683956
# -0.003803011598380597
# update weights for neuron -0.04756002391272284
# -0.13147986501661485
# -0.13071095932694454
# update weights for neuron -0.2621908243435594
# 0.06701347253611117
# 0.06662157191839249
# update weights for neuron -0.12855577988905573
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.14289624284817432
# layer 1 neuron 1 th ->
# update delta:  0.06934999028665187
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.2518878906486666], 'output': 0.7367242057344282, 'delta': -0.14289624284817432}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.03854349367619625], 'output': 0.6808474731082906, 'delta': 0.06934999028665187}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.2518878906486666], 'output': 0.7367242057344282, 'delta': -0.14289624284817432}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.03854349367619625], 'output': 0.6808474731082906, 'delta': 0.06934999028665187}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.011784957656331444
# layer 0 neuron 1 th ->
# update delta:  -0.0038475709152510987
# -0.10223944145298305
# 0.0028527688491001048
# update weights for neuron -0.09938667260388295
# -0.03337928847921452
# 0.0009313763164719524
# update weights for neuron -0.13183458476662552
# -0.12109299708908107
# -0.13202647218785107
# update weights for neuron -0.25311946927693213
# 0.05876850226798407
# 0.06407470470400381
# update weights for neuron -0.13027626230494424
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.1406282915380178
# layer 1 neuron 1 th ->
# update delta:  0.06306592037426643
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.32333601207275375], 'output': 0.7499824430756299, 'delta': -0.1406282915380178}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.0038684985328703153], 'output': 0.699800253356473, 'delta': 0.06306592037426643}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.32333601207275375], 'output': 0.7499824430756299, 'delta': -0.1406282915380178}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.0038684985328703153], 'output': 0.699800253356473, 'delta': 0.06306592037426643}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0007622070880201552
# layer 0 neuron 1 th ->
# update delta:  -0.0009354678487149611
# -0.005848991570125697
# -0.0026742515957495377
# update weights for neuron -0.008523243165875235
# -0.007178552452811543
# -0.0032821478919810563
# update weights for neuron -0.018983943510667838
# -0.13942495901980193
# -0.13833071991438511
# update weights for neuron -0.27775567893418707
# 0.06252627595458682
# 0.06203555537810902
# update weights for neuron -0.15319384760149124
# >epoch=1, lrate=0.500, error=6.171, accuracy -517.11%
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.05569764186381909
# layer 1 neuron 1 th ->
# update delta:  -0.14737184460607555
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.39365015784176266], 'output': 0.7223128892300984, 'delta': 0.05569764186381909}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.027664461654262902], 'output': 0.6941536837503781, 'delta': -0.14737184460607555}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.39365015784176266], 'output': 0.7223128892300984, 'delta': 0.05569764186381909}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, 0.027664461654262902], 'output': 0.6941536837503781, 'delta': -0.14737184460607555}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0011194637693901683
# layer 0 neuron 1 th ->
# update delta:  -0.006170709804006776
# 0.0031133223298451793
# 0.0028552337673474833
# update weights for neuron 0.005968556097192663
# -0.017161259836282458
# -0.01573862368989416
# update weights for neuron -0.026931327428983954
# 0.05368325597534445
# 0.05095660208207646
# update weights for neuron 0.1046398580574209
# -0.14204192839779534
# -0.13482740368172708
# update weights for neuron -0.1722294740221015
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.05653419807292026
# layer 1 neuron 1 th ->
# update delta:  -0.1481307925872586
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.3658013369098531], 'output': 0.7197346464728899, 'delta': 0.05653419807292026}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.046021460648774874], 'output': 0.6708240343636432, 'delta': -0.1481307925872586}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.3658013369098531], 'output': 0.7197346464728899, 'delta': 0.05653419807292026}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.046021460648774874], 'output': 0.6708240343636432, 'delta': -0.1481307925872586}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.001546866370598226
# layer 0 neuron 1 th ->
# update delta:  -0.008684638750355302
# 0.0022669162260159133
# 0.0036538918432111787
# update weights for neuron 0.0059208080692270924
# -0.012727245788305057
# -0.020514202968215562
# update weights for neuron -0.027320640687293528
# 0.05371411922945407
# 0.04944766920706623
# update weights for neuron 0.1031617884365203
# -0.14074162764850087
# -0.12956268384292913
# update weights for neuron -0.1671425230549097
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.04835278939122703
# layer 1 neuron 1 th ->
# update delta:  -0.14811803834365672
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.337534237873393], 'output': 0.7452884978711599, 'delta': 0.04835278939122703}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.12008685694240417], 'output': 0.6721389542815536, 'delta': -0.14811803834365672}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.337534237873393], 'output': 0.7452884978711599, 'delta': 0.04835278939122703}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.12008685694240417], 'output': 0.6721389542815536, 'delta': -0.14811803834365672}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.00019368172979385473
# layer 0 neuron 1 th ->
# update delta:  -0.002576764084253246
# 0.000657851943083375
# 0.0008522564622974254
# update weights for neuron 0.0015101084053808006
# -0.008752138167588979
# -0.011338518325699168
# update weights for neuron -0.018580548087907347
# 0.04800737471598663
# 0.046851580254365574
# update weights for neuron 0.09485895497035221
# -0.14705993715123614
# -0.14351941734794976
# update weights for neuron -0.1957203995288337
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.05595044722395692
# layer 1 neuron 1 th ->
# update delta:  -0.14689307811805222
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.3133578431777795], 'output': 0.7215330431479084, 'delta': 0.05595044722395692}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.19414587611423254], 'output': 0.6305826911498044, 'delta': -0.14689307811805222}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.3133578431777795], 'output': 0.7215330431479084, 'delta': 0.05595044722395692}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.19414587611423254], 'output': 0.6305826911498044, 'delta': -0.14689307811805222}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0022569959062909537
# layer 0 neuron 1 th ->
# update delta:  -0.010529558621104142
# 0.0031328687364745064
# 0.004175939681205351
# update weights for neuron 0.007308808417679858
# -0.014615766435812165
# -0.01948200328980939
# update weights for neuron -0.026788961307941696
# 0.05172014372417849
# 0.04703963964377388
# update weights for neuron 0.09875978336795238
# -0.1357867807909068
# -0.12349852063165025
# update weights for neuron -0.1605255180546047
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.047517301358848275
# layer 1 neuron 1 th ->
# update delta:  -0.1469927136385274
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.285382619565801], 'output': 0.7479479766414657, 'delta': 0.047517301358848275}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.26759241517325866], 'output': 0.6320712967603171, 'delta': -0.1469927136385274}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.285382619565801], 'output': 0.7479479766414657, 'delta': 0.047517301358848275}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.26759241517325866], 'output': 0.6320712967603171, 'delta': -0.1469927136385274}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0006256509800063516
# layer 0 neuron 1 th ->
# update delta:  -0.00522447651931098
# 0.0019170398498183356
# 0.001880272627226392
# update weights for neuron 0.0037973124770447277
# -0.01600817388931072
# -0.015701150489283538
# update weights for neuron -0.02791201190154953
# 0.04638060516915364
# 0.04440569081768174
# update weights for neuron 0.09078629598683538
# -0.14347639320938596
# -0.13736708120249796
# update weights for neuron -0.19005717842504855
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.13876096929206702
# layer 1 neuron 1 th ->
# update delta:  0.0885419832069457
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.2616239688863769], 'output': 0.7593538371423006, 'delta': -0.13876096929206702}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.34108877199252235], 'output': 0.6230133809390995, 'delta': 0.0885419832069457}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.2616239688863769], 'output': 0.7593538371423006, 'delta': -0.13876096929206702}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.34108877199252235], 'output': 0.6230133809390995, 'delta': 0.0885419832069457}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0013911179875328503
# layer 0 neuron 1 th ->
# update delta:  -0.0008363371838107814
# -0.010610795872263679
# -0.0038384593274285944
# update weights for neuron -0.014449255199692274
# -0.006379187974945591
# -0.0023076736070153426
# update weights for neuron -0.02313611678165321
# -0.1365291656000466
# -0.13540560122711062
# update weights for neuron -0.2719347668271572
# 0.08711789164843156
# 0.08640095648757212
# update weights for neuron -0.09841591869115354
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.14260539656094204
# layer 1 neuron 1 th ->
# update delta:  0.08738631060054011
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.3310044535324104], 'output': 0.7385757466905093, 'delta': -0.14260539656094204}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.2968177803890495], 'output': 0.6265360703537374, 'delta': 0.08738631060054011}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.3310044535324104], 'output': 0.7385757466905093, 'delta': -0.14260539656094204}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.2968177803890495], 'output': 0.6265360703537374, 'delta': 0.08738631060054011}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0032912920527132005
# layer 0 neuron 1 th ->
# update delta:  -0.00217009269914664
# -0.01755062150110246
# -0.006874280705641501
# update weights for neuron -0.02442490220674396
# -0.0115718918209132
# -0.004532513715669692
# update weights for neuron -0.04052930774332685
# -0.13721191509987446
# -0.13427228183292966
# update weights for neuron -0.2714841969328041
# 0.08408127125742038
# 0.08227991091684489
# update weights for neuron -0.10512301475853886
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.14439072521834756
# layer 1 neuron 1 th ->
# update delta:  0.08326044158251654
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.40230715181288146], 'output': 0.7262170063557573, 'delta': -0.14439072521834756}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.2531246250887794], 'output': 0.6390443372022169, 'delta': 0.08326044158251654}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.40230715181288146], 'output': 0.7262170063557573, 'delta': -0.14439072521834756}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.2531246250887794], 'output': 0.6390443372022169, 'delta': 0.08326044158251654}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.003518362941338997
# layer 0 neuron 1 th ->
# update delta:  -0.001953191928168457
# -0.024356207743409443
# -0.006231244783279839
# update weights for neuron -0.030587452526689284
# -0.013521160027656668
# -0.0034592272645164036
# update weights for neuron -0.047567839818862354
# -0.13862164825801826
# -0.1377156771523511
# update weights for neuron -0.27633732541036937
# 0.07993380204584148
# 0.07941138930634743
# update weights for neuron -0.11699213405818044
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.14754416984493798
# layer 1 neuron 1 th ->
# update delta:  0.08232982092244173
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.47450251442205527], 'output': 0.6909495753013603, 'delta': -0.14754416984493798}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.21149440429752114], 'output': 0.6418535947496511, 'delta': 0.08232982092244173}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.47450251442205527], 'output': 0.6909495753013603, 'delta': -0.14754416984493798}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.21149440429752114], 'output': 0.6418535947496511, 'delta': 0.08232982092244173}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.012192280703159196
# layer 0 neuron 1 th ->
# update delta:  -0.0034040806759675145
# -0.10577313941041468
# 0.002951368991196201
# update weights for neuron -0.10282177041921847
# -0.02953182498579726
# 0.0008240212307429471
# update weights for neuron -0.13152957417427277
# -0.12488823422293927
# -0.1360962302241599
# update weights for neuron -0.26098446444709916
# 0.06968778210416905
# 0.07594185710184403
# update weights for neuron -0.11535482524108609
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.14658774324503873
# layer 1 neuron 1 th ->
# update delta:  0.07508011401619236
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.5482745993445243], 'output': 0.7054246757775003, 'delta': -0.14658774324503873}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.17032949383630028], 'output': 0.6636484643569609, 'delta': 0.07508011401619236}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.5482745993445243], 'output': 0.7054246757775003, 'delta': -0.14658774324503873}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.17032949383630028], 'output': 0.6636484643569609, 'delta': 0.07508011401619236}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0007982841273785947
# layer 0 neuron 1 th ->
# update delta:  -0.0008672709124331138
# -0.006125837984176659
# -0.00280083016158895
# update weights for neuron -0.008926668145765608
# -0.006655225772057328
# -0.0030428746438790435
# update weights for neuron -0.01862476856170198
# -0.14532379681537133
# -0.14414224545603307
# update weights for neuron -0.2894660422714044
# 0.07443273900414134
# 0.07382756555095014
# update weights for neuron -0.1412057377163129
# >epoch=2, lrate=0.500, error=5.820, accuracy -482.02%
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.07161376411578302
# layer 1 neuron 1 th ->
# update delta:  -0.14808606828649956
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.6215684709670436], 'output': 0.6740488034310574, 'delta': 0.07161376411578302}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.1327894368282041], 'output': 0.6587562396569875, 'delta': -0.14808606828649956}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.6215684709670436], 'output': 0.6740488034310574, 'delta': 0.07161376411578302}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.1327894368282041], 'output': 0.6587562396569875, 'delta': -0.14808606828649956}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0014909110715835418
# layer 0 neuron 1 th ->
# update delta:  -0.005332427137655105
# 0.004146348330239414
# 0.003802623856256205
# update weights for neuron 0.00794897218649562
# -0.014829925660727555
# -0.01360055273039072
# update weights for neuron -0.020481506204622656
# 0.06900439676860194
# 0.0653986032631966
# update weights for neuron 0.13440300003179856
# -0.14269030455406287
# -0.1352340873050272
# update weights for neuron -0.1435213918272915
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.07201052312248143
# layer 1 neuron 1 th ->
# update delta:  -0.14711240076785373
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.5857615889091521], 'output': 0.6728580315221888, 'delta': 0.07201052312248143}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.20683247097145388], 'output': 0.6339437909210962, 'delta': -0.14711240076785373}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.5857615889091521], 'output': 0.6728580315221888, 'delta': 0.07201052312248143}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.20683247097145388], 'output': 0.6339437909210962, 'delta': -0.14711240076785373}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.002039964417076066
# layer 0 neuron 1 th ->
# update delta:  -0.007366553284766713
# 0.0029895461724831498
# 0.004818651103723098
# update weights for neuron 0.007808197276206248
# -0.010795605547097308
# -0.017400720237637623
# update weights for neuron -0.020388128508528683
# 0.06839262729068424
# 0.06281863073855715
# update weights for neuron 0.13121125802924138
# -0.13972129571174377
# -0.12833401536578065
# update weights for neuron -0.13684405304828304
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.06206065684004513
# layer 1 neuron 1 th ->
# update delta:  -0.1472231702353637
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.5497563273479114], 'output': 0.702849024179355, 'delta': 0.06206065684004513}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.28038867135538076], 'output': 0.6357722403194122, 'delta': -0.1472231702353637}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -0.5497563273479114], 'output': 0.702849024179355, 'delta': 0.06206065684004513}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.28038867135538076], 'output': 0.6357722403194122, 'delta': -0.1472231702353637}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.00025906780481038026
# layer 0 neuron 1 th ->
# update delta:  -0.0022714718429304305
# 0.0008799397804131996
# 0.0011399743850793512
# update weights for neuron 0.002019914165492551
# -0.007715194237068254
# -0.009995142851752478
# ...
# update delta:  -0.13301324352452373
# layer 1 neuron 1 th ->
# update delta:  0.10903439891479315
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.2818481369831074], 'output': 0.5346153223405931, 'delta': -0.13301324352452373}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.6162629259926773], 'output': 0.5579285397508661, 'delta': 0.10903439891479315}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.2818481369831074], 'output': 0.5346153223405931, 'delta': -0.13301324352452373}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.6162629259926773], 'output': 0.5579285397508661, 'delta': 0.10903439891479315}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0007350083986846891
# layer 0 neuron 1 th ->
# update delta:  -0.00024037748112118798
# -0.005640275451970939
# -0.002578823280399441
# update weights for neuron -0.00821909873237038
# -0.0018445982500345092
# -0.000843379538939151
# update weights for neuron -0.01090707652134404
# -0.1318330389725801
# -0.1306516288584792
# update weights for neuron -0.2624846678310593
# 0.1080669546926398
# 0.10709852223997879
# update weights for neuron -0.047319190898440694
# >epoch=8, lrate=0.500, error=5.149, accuracy -414.93%
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.1253083288619597
# layer 1 neuron 1 th ->
# update delta:  -0.1372354499811455
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.3483547587453693], 'output': 0.4987636197198644, 'delta': 0.1253083288619597}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.5617457265352808], 'output': 0.5558866395287293, 'delta': -0.1372354499811455}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.3483547587453693], 'output': 0.4987636197198644, 'delta': 0.1253083288619597}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.5617457265352808], 'output': 0.5558866395287293, 'delta': -0.1372354499811455}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0028039835885467026
# layer 0 neuron 1 th ->
# update delta:  -0.0013240459597263937
# 0.007798112772776383
# 0.0071516638983930925
# update weights for neuron 0.014949776671169476
# -0.003682282504241334
# -0.003377028213954815
# update weights for neuron 0.007890465952973326
# 0.12061389575254083
# 0.11379046691987499
# update weights for neuron 0.23440436267241582
# -0.1320941904493295
# -0.12462129271962806
# update weights for neuron -0.022311120496541728
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.12406637685810641
# layer 1 neuron 1 th ->
# update delta:  -0.13200394230259954
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.2857005943143893], 'output': 0.5037072095608147, 'delta': 0.12406637685810641}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.6303634515258535], 'output': 0.5299123186279752, 'delta': -0.13200394230259954}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.2857005943143893], 'output': 0.5037072095608147, 'delta': 0.12406637685810641}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.6303634515258535], 'output': 0.5299123186279752, 'delta': -0.13200394230259954}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0037732581755695535
# layer 0 neuron 1 th ->
# update delta:  -0.0014525689177983068
# 0.005529669754109291
# 0.008912907754734852
# update weights for neuron 0.014442577508844142
# -0.00212872431113096
# -0.003431149465349563
# update weights for neuron 0.00888270373236362
# 0.11766412072439697
# 0.10736704331257135
# update weights for neuron 0.22503116403696832
# -0.12519208021165443
# -0.11423621249811108
# update weights for neuron -0.014397128672797188
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.11247494420503133
# layer 1 neuron 1 th ->
# update delta:  -0.133058848197768
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.223667405885336], 'output': 0.546222245748752, 'delta': 0.11247494420503133}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.6963654226771533], 'output': 0.5348307844147207, 'delta': -0.133058848197768}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.223667405885336], 'output': 0.546222245748752, 'delta': 0.11247494420503133}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.6963654226771533], 'output': 0.5348307844147207, 'delta': -0.133058848197768}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0005101579867367042
# layer 0 neuron 1 th ->
# update delta:  -0.0007280716433458997
# 0.0017327830725771016
# 0.002244844887805187
# update weights for neuron 0.0039776279603822885
# -0.002472940249907883
# -0.0032037289408633584
# update weights for neuron -0.0016990412303889528
# 0.11164337475055446
# 0.1087083415196097
# update weights for neuron 0.22035171627016414
# -0.13207509421957142
# -0.1286029240941097
# update weights for neuron -0.040326302043516976
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.1192701275394651
# layer 1 neuron 1 th ->
# update delta:  -0.12225768670869631
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.1674299337828205], 'output': 0.5219945312756151, 'delta': 0.1192701275394651}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.7628948467760372], 'output': 0.4892566269601067, 'delta': -0.12225768670869631}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.1674299337828205], 'output': 0.5219945312756151, 'delta': 0.1192701275394651}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.7628948467760372], 'output': 0.4892566269601067, 'delta': -0.12225768670869631}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.005342994339653732
# layer 0 neuron 1 th ->
# update delta:  -0.001143371594324434
# 0.00741645116821208
# 0.009885716680843332
# update weights for neuron 0.017302167849055413
# -0.0015870800261745203
# -0.00211548935369975
# update weights for neuron 0.013599598469181141
# 0.10996089078276933
# 0.09900773391159445
# update weights for neuron 0.20896862469436378
# -0.11271526586638943
# -0.10148774688193789
# update weights for neuron -0.005234388053963535
# target for each row-> [1, 0]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  0.10693585772134002
# layer 1 neuron 1 th ->
# update delta:  -0.12379035965584227
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.107794870013088], 'output': 0.5649214930897509, 'delta': 0.10693585772134002}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.8240236901303855], 'output': 0.49520694492659884, 'delta': -0.12379035965584227}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.107794870013088], 'output': 0.5649214930897509, 'delta': 0.10693585772134002}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.8240236901303855], 'output': 0.49520694492659884, 'delta': -0.12379035965584227}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  0.0015941681509935588
# layer 0 neuron 1 th ->
# update delta:  -0.001245645918815203
# 0.004884646504884944
# 0.004790963066147308
# update weights for neuron 0.009675609571032251
# -0.003816749180362631
# -0.0037435471200584027
# update weights for neuron 0.0021153132706112176
# 0.10429428594987339
# 0.09944294066563837
# update weights for neuron 0.20373722661551175
# -0.12073244132410088
# -0.11511646002141122
# update weights for neuron -0.03211167473000036
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.14241403232624336
# layer 1 neuron 1 th ->
# update delta:  0.12768338620106787
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.0543269411524179], 'output': 0.5877661283664134, 'delta': -0.14241403232624336}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.8859188699583066], 'output': 0.4890200412545402, 'delta': 0.12768338620106787}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.0543269411524179], 'output': 0.5877661283664134, 'delta': -0.14241403232624336}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.8859188699583066], 'output': 0.4890200412545402, 'delta': 0.12768338620106787}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0014561977802362495
# layer 0 neuron 1 th ->
# update delta:  -0.0001416078412810019
# -0.011107194022509505
# -0.004018031541696713
# update weights for neuron -0.015125225564206219
# -0.0010801182295179998
# -0.00039073316862654257
# update weights for neuron -0.016596076962350763
# -0.1400492298236017
# -0.13872489921210657
# update weights for neuron -0.2787741290357083
# 0.12556318788702572
# 0.12437583988371895
# update weights for neuron -0.028835101264963636
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.13793806141777387
# layer 1 neuron 1 th ->
# update delta:  0.12569861832428234
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.1255339573155396], 'output': 0.5597438951003648, 'delta': -0.13793806141777387}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.8220771768577727], 'output': 0.4971896416890798, 'delta': 0.12569861832428234}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.1255339573155396], 'output': 0.5597438951003648, 'delta': -0.13793806141777387}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.8220771768577727], 'output': 0.4971896416890798, 'delta': 0.12569861832428234}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.00323665268094525
# layer 0 neuron 1 th ->
# update delta:  -0.00021891450622119036
# -0.017259260261322237
# -0.006760159450797781
# update weights for neuron -0.024019419712120016
# -0.001167348742759428
# -0.0004572306991294822
# update weights for neuron -0.025643999154008928
# -0.13255569234318632
# -0.12932757588135682
# update weights for neuron -0.2618832682245431
# 0.1207938346189502
# 0.11785215358565743
# update weights for neuron -0.02323728001993547
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.1351226482618437
# layer 1 neuron 1 th ->
# update delta:  0.12098051070255411
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.1945029880244267], 'output': 0.5448807705773022, 'delta': -0.1351226482618437}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.7592278676956316], 'output': 0.5156060622089169, 'delta': 0.12098051070255411}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.1945029880244267], 'output': 0.5448807705773022, 'delta': -0.1351226482618437}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.7592278676956316], 'output': 0.5156060622089169, 'delta': 0.12098051070255411}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0033438837383601133
# layer 0 neuron 1 th ->
# update delta:  -0.00025645663632086494
# -0.023148358585857523
# -0.005922231005713382
# update weights for neuron -0.029070589591570904
# -0.001775345868391226
# -0.00045420103151828635
# update weights for neuron -0.03130013649148042
# -0.12955323556074758
# -0.12845001882052154
# update weights for neuron -0.25800325438126914
# 0.11599400102738688
# 0.1150062485938384
# update weights for neuron -0.02700300476004386
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.12563753798206634
# layer 1 neuron 1 th ->
# update delta:  0.11901285397413447
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.2620643121553485], 'output': 0.5025633609404133, 'delta': -0.12563753798206634}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.6987376123443545], 'output': 0.5229440398064763, 'delta': 0.11901285397413447}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.2620643121553485], 'output': 0.5025633609404133, 'delta': -0.12563753798206634}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.6987376123443545], 'output': 0.5229440398064763, 'delta': 0.11901285397413447}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.010431638780797003
# layer 0 neuron 1 th ->
# update delta:  2.831506839591333e-05
# -0.09049883363942121
# 0.0025251727691133702
# update weights for neuron -0.08797366087030783
# 0.0002456450724662471
# -6.854190522831747e-06
# update weights for neuron -0.08773486998836443
# -0.1058112927997366
# -0.11525585836498446
# update weights for neuron -0.22106715116472106
# 0.10023201776356812
# 0.10917858517104492
# update weights for neuron -0.011656548230108019
# target for each row-> [0, 1]
# output layer 1
# set error in output layer 0
# set error in output layer 1
# layer 1 neuron 0 th ->
# update delta:  -0.13067093599884597
# layer 1 neuron 1 th ->
# update delta:  0.11071689117119189
# hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.3248830811463816], 'output': 0.5238785779331966, 'delta': -0.13067093599884597}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.6392311853572873], 'output': 0.5522439581404136, 'delta': 0.11071689117119189}
# set error in hidden layer 0
# get error delta from previous layer  {'weights': [0.651592972722763, 0.7887233511355132, -1.3248830811463816], 'output': 0.5238785779331966, 'delta': -0.13067093599884597}
# get error delta from previous layer  {'weights': [0.02834747652200631, 0.8357651039198697, -0.6392311853572873], 'output': 0.5522439581404136, 'delta': 0.11071689117119189}
# set error in hidden layer 1
# layer 0 neuron 0 th ->
# update delta:  -0.0007230036788420354
# layer 0 neuron 1 th ->
# update delta:  -0.00018423257914448505
# -0.005548154155455857
# -0.0025367039644020885
# update weights for neuron -0.008084858119857945
# -0.001413755945457849
# -0.0006463916126074702
# update weights for neuron -0.010145005677923263
# -0.12950853498830708
# -0.1283432359307464
# update weights for neuron -0.2578517709190535
# 0.10973199406919015
# 0.10874464146509634
# update weights for neuron -0.03937513538476699
# >epoch=9, lrate=0.500, error=5.141, accuracy -414.10%

# %%
# plt.plot(range(epoch), error_history[:epoch], color='green', marker='o', linestyle='dashed',linewidth=1, markersize=3)
plt.plot(range(epoch), error_history[:epoch], marker='o',color='blue', markersize=3, linestyle='dashed',linewidth=1)
# plt.ylim(0, 9)
plt.show()

# %%
# Making predictions

# %%
def predict(network, row):
    outputs = forward_propagate(network, row)
    return outputs.index(max(outputs))

# %%
network
# Out:
# [[{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614],
#    'output': 0.9643898158763548,
#    'delta': -0.002093402425365238},
#   {'weights': [0.2550690257394217, 0.49543508709194095, 0.4494910647887381],
#    'output': 0.9185258960543243,
#    'delta': -0.004948740881233178},
#   {'weights': [0.651592972722763, 0.7887233511355132, 0.0938595867742349],
#    'output': 0.9805002682334348,
#    'delta': 5.104168915258216e-05},
#   {'weights': [0.02834747652200631, 0.8357651039198697, 0.43276706790505337],
#    'output': 0.9335939598856237,
#    'delta': 0.00037781873566704755}],
#  [{'weights': [0.762280082457942,
#     0.0021060533511106927,
#     0.4453871940548014,
#     0.7215400323407826,
#     0.22876222127045265],
#    'output': 0.8885643239851334,
#    'delta': 0.011034111705730125},
#   {'weights': [0.9452706955539223,
#     0.9014274576114836,
#     0.030589983033553536,
#     0.0254458609934608,
#     0.5414124727934966],
#    'output': 0.911714898040579,
#    'delta': -0.0733847004740911}]]

# %%
# Test makeing preductions with the network
# get 10 data sets with 2 features and 1 target value as the last elements {0, 1}

dataset = [[2.7810836,2.550537003,0],
	[1.465489372,2.362125076,0],
	[3.396561688,4.400293529,0],
	[1.38807019,1.850220317,0],
	[3.06407232,3.005305973,0],
	[7.627531214,2.759262235,1],
	[5.332441248,2.088626775,1],
	[6.922596716,1.77106367,1],
	[8.675418651,-0.242068655,1],
	[7.673756466,3.508563011,1],
    [7.673756466,3.508563011,1],
    [9.673756466,3.508563011,1]]

# len(dataset)

# load trained model from previously performed
network = network

# making predictions row by row
for row in dataset:
    prediction = predict(network, row)
    print('Expected %d, Got %d' %(row[-1], prediction))
# Out:
# Expected 0, Got 0
# Expected 0, Got 0
# Expected 0, Got 0
# Expected 0, Got 0
# Expected 0, Got 0
# Expected 1, Got 1
# Expected 1, Got 1
# Expected 1, Got 1
# Expected 1, Got 1
# Expected 1, Got 1
# Expected 1, Got 1
# Expected 1, Got 1
