# %% [markdown]
# #  Machine Learning from zero to Master  - Culculate Gradient Descent Derivative for Linear Regression
#
# ### Reference Link
# - https://towardsdatascience.com/gradient-descent-in-python-a0d07285742f
# - http://sofasofa.io/tutorials/python_gradient_descent/index.php (implemented by Chinese)
# - back-propogation https://www.youtube.com/watch?v=d14TUNcbn1k
# - Power Rule - https://www.mathsisfun.com/calculus/power-rule.html
# - ML guide - https://ml-cheatsheet.readthedocs.io/en/latest/gradient_descent.html#step-by-step
# - Math Behand Gradient Descent  https://medium.com/datadriveninvestor/the-math-and-intuition-behind-gradient-descent-13c45f367a11
# - Google Developer - https://developers.google.com/machine-learning/crash-course/generalization/video-lecture
# - Anther explanation of Gradient descent - https://www.kdnuggets.com/2020/05/5-concepts-gradient-descent-cost-function.html#:~:text=Gradient%20descent%20is%20an%20iterative,the%20best%20set%20of%20parameters.
#
# This tutorial is used to calculate derivate of Gradient Descent in Python. Spaired by Machine Learning

# %%
# generate some sample data

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib

# %%
# np.random.seed(123)
X = 2 * np.random.rand(100,1)
y = 4 + 2 * X + np.random.randn(100,1)

plt.scatter(X, y, marker='o')
plt.xlabel("X")
plt.ylabel("y")
# print("X->",X,"\n y->",y)
# Out:
# Text(0, 0.5, 'y')

# %%
# x = np.linspace(0, 2, 100)

# # Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
# fig, ax = plt.subplots()  # Create a figure and an axes.
# ax.plot(x, x, label='linear')  # Plot some data on the axes.
# ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
# ax.plot(x, x**3, label='cubic')  # ... and some more.
# ax.set_xlabel('x label')  # Add an x-label to the axes.
# ax.set_ylabel('y label')  # Add a y-label to the axes.
# ax.set_title("Simple Plot")  # Add a title to the axes.
# ax.legend()  # Add a legend.

## some helps
# import matplotlib
# matplotlib.colors
# matplotlib.axes.Axes.imshow
# matplotlib.figure.Figure.text
# matplotlib.axes.Axes.set_axis_off

# %%
# the best theta
theta_best = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
theta_best
# Out:
# array([[4.91484967]])

# %% [markdown]
#     Like climb down from the mountain ->
#     Size of Steps took in any direction = Learning rate
#     Gadget tells you height = Cost function
#     The direction of your steps = Gradients

# %% [markdown]
# Images for equation
# ![image.png](attachment:image.png)

# %% [markdown]
# gradient descents
# ![image.png](attachment:image.png)

# %%
# implement cost function into python code
def cal_cost_function(theta, X, y):
    m = len(y)
    
    predictions = X.dot(theta)
    cost = (1/2*m) * np.sum(np.square(predictions - y))
#     '''
    
#     Calculates the cost for given X and Y. The following shows and example of a single dimensional X
#     theta = Vector of thetas 
#     X     = Row of X's np.zeros((2,j))
#     y     = Actual y's np.zeros((2,1))
    
#     where:
#         j is the no of features
#     '''
    
#     m = len(y)
    
#     predictions = X.dot(theta)
#     cost = (1/2*m) * np.sum(np.square(predictions-y))
    return cost

# %%
cal_cost_function(theta_best, X, y)
# Out:
# 22652.32026369211

# %%
# def gradient_descent(X, y, theta, learning_rate=0.01, interation=100):
#     '''
#     X = Matrix with bias added units
#     y = Vector y(result, moving steps)
#     theta = Vector of thetas
#     learning rate
#     interation = total moving steps numbers
    
#     Returns final theta and array of theta of history
#     '''  
#     m = len(y)
    
#     cost_history = np.zeros(interation)
#     theta_history = np.zeros((interation,2))
    
#     for i in range(interation):
#         predictions = np.dot(X, theta)
#         theta = theta - learning_rate*(1/m)*(X.T.dot(predictions - y))
#         theta_history[i,:] = theta.T
#         cost_history[i] = cal_cost_function(theta, X, y)
    
#     return theta, cost_history, theta_history

def gradient_descent(X,y,theta,learning_rate=0.01,iterations=100):
    '''
    X    = Matrix of X with added bias units
    y    = Vector of Y
    theta=Vector of thetas np.random.randn(j,1)
    learning_rate 
    iterations = no of iterations
    
    Returns the final theta vector and array of cost history over no of iterations
    '''
    m = len(y)
    cost_history = np.zeros(iterations)
    theta_history = np.zeros((iterations,2))
    for it in range(iterations):
        
        prediction = np.dot(X,theta)
        # print(X.T)
        theta = theta - (1/m)*learning_rate*( X.T.dot((prediction - y)))
        theta_history[it,:] =theta.T
        cost_history[it]  = cal_cost_function(theta,X,y)
#         print(cost_history[it])
        
    return theta, cost_history, theta_history

# %%
lr =0.01
n_iter = 2000

theta = np.random.randn(2,1)

X_b = np.c_[np.ones((len(X),1)),X]
theta,cost_history,theta_history = gradient_descent(X_b,y,theta,lr,n_iter)


print('Theta0:          {:0.3f},\nTheta1:          {:0.3f}'.format(theta[0][0],theta[1][0]))
print('Final cost/MSE:  {:0.3f}'.format(cost_history[-1]))
# Out:
# Theta0:          3.761,
# Theta1:          2.062
# Final cost/MSE:  6583.401

# %%
print("Theta 0 {}, Theta 1 {}\n".format(theta[0], theta[1]),
"Cost_history : {}\n".format(cost_history),
)
# print("Theta_history : {}\n".format(theta_history))
# Out:
# Theta 0 [3.76111778], Theta 1 [2.06241687]
#  Cost_history : [116850.16197188 112037.65242605 107435.57493651 ...   6583.40659749
#    6583.40383209   6583.40107422]

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.set_ylabel('J(Theta)')
ax.set_xlabel('Iterations')
_=ax.plot(range(n_iter),cost_history,'b.')

# %%
plt.plot(range(n_iter), theta_history)
plt.title("theta history function learning progress")
plt.xlabel("interations")
plt.ylabel("predictions")
# Out:
# Text(0, 0.5, 'predictions')

# %%
fig,ax = plt.subplots(figsize=(12,8))

ax.set_ylabel('J(Theta)')
ax.set_xlabel('Iterations')
_=ax.plot(range(n_iter), cost_history,'b.')

# %%
def plot_GD(n_iter,lr,ax,ax1=None):
     """
     n_iter = no of iterations
     lr = Learning Rate
     ax = Axis to plot the Gradient Descent
     ax1 = Axis to plot cost_history vs Iterations plot

     """
     _ = ax.plot(X,y,'b.')
     theta = np.random.randn(2,1)

     tr =0.1
     cost_history = np.zeros(n_iter)
     for i in range(n_iter):
        pred_prev = X_b.dot(theta)
        theta,h,_ = gradient_descent(X_b,y,theta,lr,1)
        pred = X_b.dot(theta)

        cost_history[i] = h[0]

        if ((i % 25 == 0) ):
            _ = ax.plot(X,pred,'r-',alpha=tr)
            if tr < 0.8:
                tr = tr+0.2
     if not ax1== None:
        _ = ax1.plot(range(n_iter),cost_history,'b.')

# %%
fig = plt.figure(figsize=(30,25),dpi=200)
fig.subplots_adjust(hspace=0.4, wspace=0.4)

it_lr =[(2000,0.001),(500,0.01),(200,0.05),(100,0.1)]
count =0
for n_iter, lr in it_lr:
    count += 1
    
    ax = fig.add_subplot(4, 2, count)
    count += 1
   
    ax1 = fig.add_subplot(4,2,count)
    
    ax.set_title("lr:{}".format(lr))
    ax1.set_title("Iterations:{}".format(n_iter))
    plot_GD(n_iter,lr,ax,ax1)

# %%
def update_weights(w, b, X, Y, learning_rate=0.01):
    
    deriv_w = 0
    deriv_b = 0
    
    N = len(X)
    for i in range(N):
        
        deriv_w += 2*X[i] *((w*X[i]+b) - Y[i])
        deriv_b += 2*((w*X[i]+b) - Y[i])
        
    w = w - deriv_w/(float(N)*2) * learning_rate
    b = b - deriv_b/(float(N)*2) * learning_rate
#     print("b here", b)
    return w,b

# %%
w=1;
b=0;
learning_rate=0.01
n_iter=100;

X=np.random.randn(100,1)*2
Y= b + w * X + np.random.randn(100,1)

def predict_model(w, b, X, Y, learning_rate=0.01, iterations=100):
    cal_history = []
    the_history = []
    
    for i in range(iterations):
        w, b = update_weights(w, b, X, Y, learning_rate=learning_rate)
        the_history.append([w, b])
#         cal_history[i] = cal_cost_function(X, Y)
    return the_history

# %%
# the_history=predict_model(x, b, X, Y, learning_rate=learning_rate, iterations=n_iter)

# %%
w, b=update_weights(x, b, X, Y, learning_rate=learning_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-5ab7fce2abbe> in <module>
# ----> 1 w, b=update_weights(x, b, X, Y, learning_rate=learning_rate)
#
# NameError: name 'x' is not defined

# %%
plt.plot(range(100), w, 'b.', label="weight", )
plt.plot(range(100), b, 'b.', color='r', label="Bias",)
# plt.ylim(10)
plt.legend()
plt.show()
